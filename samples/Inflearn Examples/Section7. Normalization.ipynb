# %%
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)
def norm_zeroone(x):
    n = x - np.min(x,0)
    d = np.max(x,0) - np.min(x,0)
    return n/(d+1e-7)
def norm_standard(x):
    n = x - np.mean(x)
    d = np.std(x)
    return n/d

xy = np.array([[828.659973, 833.450012, 908100, 828.349976, 831.659973], 
               [823.02002, 828.070007, 1828100, 821.655029, 828.070007], 
               [819.929993, 824.400024, 1438100, 818.97998, 824.159973], 
               [816, 820.958984, 1008100, 815.48999, 819.23999], 
               [819.359985, 823, 1188100, 818.469971, 818.97998], 
               [819, 823, 1198100, 816, 820.450012], 
               [811.700012, 815.25, 1098100, 809.780029, 813.669983], 
               [809.51001, 816.659973, 1398100, 804.539978, 809.559998]])
xy = norm_zeroone(xy)
print(xy)
x_data = xy[:,0:-1]
y_data = xy[:,[-1]]

X = tf.placeholder("float",[None,4])
Y = tf.placeholder("float",[None,1])
W = tf.Variable(tf.random_normal([4,1]),name='weight')
b = tf.Variable(tf.random_normal([1]),name='bias')

hypothesis = tf.matmul(X,W)+b
cost = tf.reduce_mean(tf.square(hypothesis-Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost,hypothesis,train],feed_dict={X:x_data,Y:y_data})
    if(step%100==0):
        print(step,"Cost : ",cost_val,"Prediction : ",hy_val)
# Out:
# [[0.99999999 0.99999999 0.         1.         1.        ]
#  [0.70548491 0.70439552 1.         0.71881782 0.83755791]
#  [0.54412549 0.50274824 0.57608696 0.606468   0.6606331 ]
#  [0.33890353 0.31368023 0.10869565 0.45989134 0.43800918]
#  [0.51436    0.42582389 0.30434783 0.58504805 0.42624401]
#  [0.49556179 0.42582389 0.31521739 0.48131134 0.49276137]
#  [0.11436064 0.         0.20652174 0.22007776 0.18597238]
#  [0.         0.07747099 0.5326087  0.         0.        ]]
# 0 Cost :  0.386387 Prediction :  [[0.80469835]
#  [0.6423676 ]
#  [0.9283773 ]
#  [1.1906192 ]
#  [1.0728735 ]
#  [0.87574637]
#  [1.279675  ]
#  [0.78469896]]
# 100 Cost :  0.38543785 Prediction :  [[0.80326784]
#  [0.6408453 ]
#  [0.9270431 ]
#  [1.1894984 ]
#  [1.0716277 ]
#  [0.87452614]
#  [1.2786683 ]
#  [0.78367335]]
# 200 Cost :  0.38449204 Prediction :  [[0.8018373 ]
#  [0.6393237 ]
#  [0.9257095 ]
#  [1.1883779 ]
#  [1.0703825 ]
#  [0.87330616]
#  [1.2776617 ]
#  [0.7826481 ]]
# 300 Cost :  0.3835499 Prediction :  [[0.8004068 ]
#  [0.63780427]
#  [0.9243771 ]
#  [1.1872574 ]
#  [1.0691378 ]
#  [0.87208676]
#  [1.2766556 ]
#  [0.7816241 ]]
# 400 Cost :  0.38261753 Prediction :  [[0.79898405]
#  [0.6362927 ]
#  [0.9230522 ]
#  [1.1861446 ]
#  [1.0679007 ]
#  [0.8708751 ]
#  [1.2756572 ]
#  [0.78060776]]
# 500 Cost :  0.38169256 Prediction :  [[0.7975676]
#  [0.6347873]
#  [0.9217334]
#  [1.185037 ]
#  [1.0666691]
#  [0.8696691]
#  [1.2746633]
#  [0.779596 ]]
# 600 Cost :  0.3807729 Prediction :  [[0.79616094]
#  [0.63329136]
#  [0.920421  ]
#  [1.183933  ]
#  [1.0654435 ]
#  [0.86846864]
#  [1.273671  ]
#  [0.77858543]]
# 700 Cost :  0.37985623 Prediction :  [[0.79475427]
#  [0.63179517]
#  [0.9191086 ]
#  [1.1828288 ]
#  [1.0642178 ]
#  [0.8672681 ]
#  [1.2726789 ]
#  [0.7775749 ]]
# 800 Cost :  0.37894785 Prediction :  [[0.7933547 ]
#  [0.6303062 ]
#  [0.917803  ]
#  [1.181731  ]
#  [1.0629985 ]
#  [0.8660739 ]
#  [1.2716925 ]
#  [0.77657056]]
# 900 Cost :  0.37804452 Prediction :  [[0.7919659 ]
#  [0.62882763]
#  [0.9165043 ]
#  [1.1806369 ]
#  [1.0617845 ]
#  [0.8648854 ]
#  [1.2707069 ]
#  [0.7755685 ]]
# 1000 Cost :  0.37714684 Prediction :  [[0.7905802 ]
#  [0.6273518 ]
#  [0.91520876]
#  [1.1795459 ]
#  [1.0605738 ]
#  [0.8637    ]
#  [1.2697242 ]
#  [0.7745695 ]]
# 1100 Cost :  0.3762546 Prediction :  [[0.7891974 ]
#  [0.6258791 ]
#  [0.91391593]
#  [1.1784577 ]
#  [1.0593662 ]
#  [0.8625174 ]
#  [1.2687445 ]
#  [0.7735734 ]]
# 1200 Cost :  0.37536612 Prediction :  [[0.7878148 ]
#  [0.6244096 ]
#  [0.91262525]
#  [1.1773701 ]
#  [1.0581594 ]
#  [0.8613358 ]
#  [1.2677658 ]
#  [0.7725791 ]]
# 1300 Cost :  0.37448552 Prediction :  [[0.7864379 ]
#  [0.6229457 ]
#  [0.9113403 ]
#  [1.1762882 ]
#  [1.0569584 ]
#  [0.8601602 ]
#  [1.2667925 ]
#  [0.77159053]]
# 1400 Cost :  0.3736117 Prediction :  [[0.7850782 ]
#  [0.62149423]
#  [0.9100657 ]
#  [1.1752143 ]
#  [1.0557675 ]
#  [0.85899264]
#  [1.2658231 ]
#  [0.770602  ]]
# 1500 Cost :  0.37274605 Prediction :  [[0.78373194]
#  [0.62005556]
#  [0.90880156]
#  [1.1741481 ]
#  [1.0545862 ]
#  [0.8578342 ]
#  [1.2648594 ]
#  [0.7696179 ]]
# 1600 Cost :  0.37188703 Prediction :  [[0.7823968 ]
#  [0.61862624]
#  [0.9075452 ]
#  [1.1730876 ]
#  [1.0534121 ]
#  [0.8566828 ]
#  [1.2638994 ]
#  [0.7686369 ]]
# 1700 Cost :  0.37103072 Prediction :  [[0.78106165]
#  [0.6171969 ]
#  [0.90628874]
#  [1.1720269 ]
#  [1.0522379 ]
#  [0.85553133]
#  [1.2629395 ]
#  [0.76765585]]
# 1800 Cost :  0.37018263 Prediction :  [[0.77973235]
#  [0.6157752 ]
#  [0.9050393 ]
#  [1.1709723 ]
#  [1.0510703 ]
#  [0.8543863 ]
#  [1.2619858 ]
#  [0.76668173]]
# 1900 Cost :  0.3693381 Prediction :  [[0.77840745]
#  [0.61435795]
#  [0.90379274]
#  [1.1699195 ]
#  [1.0499051 ]
#  [0.8532436 ]
#  [1.2610323 ]
#  [0.76570857]]
# 2000 Cost :  0.36849922 Prediction :  [[0.77709264]
#  [0.61294836]
#  [0.9025524 ]
#  [1.1688714 ]
#  [1.0487452 ]
#  [0.85210663]
#  [1.2600814 ]
#  [0.7647385 ]]
